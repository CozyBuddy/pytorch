# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import metrics

names = ['sepal-length','sepal-width','pedal-length','pedal-width','Class']

dataset = pd.read_csv('iris.data' , names=names)

# %%
x = dataset.iloc[:, :-1].values
y = dataset.iloc
